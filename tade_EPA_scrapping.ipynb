# %% [markdown]
#
# # **Addis Ababa University**
# ## **Institute of Techonology**
# ## **School Of Information Techonology and Engineering**
# ## ***Ethiopian press Agency Web scrapping  Assignment***
#
# By:
# # **Name: Tadele Melesse**
# ### ID: GSR/5701/14

# %%
# Imports
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#let check existance of page
url = 'https://www.press.et/?p=89588'
response = requests.get(url)
so = soup(response.content, 'html.parser')
so
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="true" name="HandheldFriendly"/>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <title>አደንዛዥ እፅ አዘዋዋሪዎቹ ብራዚላውያን – የኢትዮጵያ ፕሬስ ድርጅት</title>
# <meta content="max-image-preview:large" name="robots">
# <link href="//fonts.googleapis.com" rel="dns-prefetch">
# <link href="https://www.press.et/?feed=rss2" rel="alternate" title="የኢትዮጵያ ፕሬስ ድርጅት » Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/14.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/www.press.et\/wp-includes\/js\/wp-emoji-release.min.js?ver=6.1.1"}};
# /*! This file is auto-generated */
# ...

# %%
for link in so.findAll('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# https://www.press.et/herald
# https://www.press.et/afanoromo/
# https://press.et/arabic/
# https://press.et/bakalcho
# https://press.et/wegahta
# https://press.et/zemen
# #
# #
# https://www.press.et/
# https://www.press.et/
# https://www.press.et/?cat=6
# https://www.press.et/?cat=8
# https://www.press.et/?cat=7
# https://www.press.et/?cat=16
# https://www.press.et/?cat=5
# https://www.press.et/?cat=61
# https://www.press.et/?cat=52
# https://www.press.et/?cat=53
# https://www.press.et/?cat=62
# https://www.press.et/?cat=134
# https://www.press.et/?cat=135
# https://www.press.et/?cat=136
# https://www.press.et/?cat=137
# https://www.press.et/?cat=17
# https://www.press.et/?cat=56
# https://www.press.et/?cat=141
# https://www.press.et/?cat=68
# https://www.press.et/?cat=25
# https://www.press.et/?cat=142
# https://www.press.et/?cat=46
# https://www.press.et/?cat=97
# https://www.press.et/?cat=29
# https://www.press.et/?cat=27
# https://www.press.et/?cat=26
# ...

# %%
so.title.string
# Out:
# 'አደንዛዥ እፅ አዘዋዋሪዎቹ ብራዚላውያን – የኢትዮጵያ ፕሬስ ድርጅት'

# %%
def lnk():
   cat=cat={5:"ወቅታዊ እና ፖለቲካ", 7:"ዓለም አቀፍ", 8:"የሀገር ውስጥ", 11:"ኢኮኖሚ", 16:"ርዕሰ አንቀፅ", 17:"ማህበራዊ", 18:"ስፖርት እና መዝናኛ"}
  links=[]
  for a in range(7):
    links.append([])
  print(links)
  for k, y in cat.items():
    count=0
    i=1
    c=0
    r=0
    while True:
        url = "https://www.press.et/?paged={}&cat={}".format(i,k)
        print(cat[k])
        req = requests.get(url)
        if req.status_code == 200:
            so =soup(req.content, 'html.parser')
            i = i + 1
            count=count+1
            for news in so.find("div",{"id":"recent-content"}).findAll('h2'):
              links[c].append(news.a['href'])
              x=links[c][r]
              r=r+1
              print(x)
              y=cat[k]
              page=requests.get(x)
              val = soup(page.content, 'html.parser')
              for news in val.find_all('p'):
                #print(news.text.strip())
                with open(y+'.txt', 'a') as f:
                  f.write(news.text.strip())
                  f.write('\n')
              print("Headline : {}".format(link.text))
              print(count)
        else:
          c=c+1
          print("The total number of pages: {}".format(count))
          break
  return links
print(lnk())
# Out:
# Streaming output truncated to the last 5000 lines.
# 4
# https://www.press.et/?p=49542
# Headline : slot gacor 2023
# 4
# https://www.press.et/?p=49535
# Headline : slot gacor 2023
# 4
# https://www.press.et/?p=49479
# Headline : slot gacor 2023
# 4
# https://www.press.et/?p=49463
# Headline : slot gacor 2023
# 4
# https://www.press.et/?p=49449
# Headline : slot gacor 2023
# 4
# https://www.press.et/?p=49399
# Headline : slot gacor 2023
# 4
# ማህበራዊ
# https://www.press.et/?p=49393
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49329
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49274
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49251
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49169
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49107
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49089
# Headline : slot gacor 2023
# 5
# https://www.press.et/?p=49099
# Headline : slot gacor 2023
# 5
# ...
